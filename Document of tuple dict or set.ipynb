# %% [markdown]
# TUPLE:
# ------
#
# s=('string',1,12.5,[4,5,6])   #immutable (once declared, cannot be changed)
#                               # indexing, slicing
#                               #single element inside a tuple should be declared with a comma
# s
#
#
#
# s1=(1)
# print(type(s1))
#
# output:
# --------
# <type 'int'>
#
#
# s1=(1,)
# print(type(s1))
#
# output:
# -------
# <type 'tuple'>
#
#
# looping through tuple:
# ----------------------
# s=('string',1,12.5,[4,5,6])
# for y in s[2:]:   #y is iterative variable
#     print(y)
#
# output:
# -------
# 12.5
# [4, 5, 6]
#
#
# sets:
# -----
# s={'string',1,12.5,1,1,4,4}    #sets are declared in flower braces as individual elements
#                              #set removes any number of duplicate values automatically and
#                                     #prints single value in the output
#                             # sets will have unordered values. the order of input and output may not be same
# s.update('lpoi')               #Once a set is created, you cannot change its items, but you can add new items.
# print(s)
# set([12.5, 1, 4, 'string', 'i', 'l', 'o', 'p'])
#
#
# s.add(7)
# print(s)
# output:
# -------
# set([12.5, 1, 4, 'string', 7])
#
#
# key error while removing the element which is not existing in parent set:
# --------------------------------------------------------------------------
#
#
# s={'string',1,1,1,4,4}
#
#
#
# s.remove(12.5)
# print(s)
#
# output:
#
# keyerror: 12.5 (12.5 not present in set)
#
#
# discard:
# --------
# s={'string',1,12.5,1,1,4,4}
# s.discard(12.5)
# print(s)
#
# output:
# ------
# set([1, 4, 'string'])
#
# if element is not present in parent set, the discard method wont show the error.
#
# example:
# -------
#
# s={'string',1,1,1,4,4}
#
# s.discard(12.5)
# print(s)
#
# output:
# ----------
# set([1, 4, 'string'])
#
# pop()
# -------
# s={'string',1,1,1,4,4,'pppp'}
#
# s.pop()      #as set is unindexed, we are not sure which element will be removed in pop() method
# print(s)     # no arguements allowed in pop() when used in set becoz set is unindexed.
#
# output:
# ------
# set(['pppp', 'string', 1])
#
#
#
# s={'string',1,1,1,4,4,'pppp'}
# s.clear()
# print(s)
#
# output:
# ------
# set([])
#
# operations on sets:
# ------------------
# s={'string',1,1,1,4,4,'pppp'}
# #union(|) (all elements in both sets),
# #intersection(&)(only common elements),
# #difference/minus (-) (present in set A and not present in set B),
# #symmetric difference (^) ==> other than common elements (opp of interesection)
#
#
# #question: i have a list with 100 elements along with duplicates. I want to print unique values from a list.
#
# s=[1,1,1,1,13,4,5,3,4,5,4,5,13,13,14,14]
# s=list(set(s))
# print(s)
#
# output:
# -------
# [1, 3, 4, 5, 13, 14]
#
#
# copy:
# -----
#
# s={1,'ddd',2,5}
# l=s.copy()
# print(l)
#
# output:
# -------
# set([1, 2, 5, 'ddd'])
#
# Union:
# ------
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
# print(s.union(s1))
#
#          or
#
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
# print(s|s1)
#
# output:
# -------
# set([0, 1, 2, 3, 4, 5, 12.3, 7, 9, 'ppp', 125, 'ddd'])
#
#
# Intersection:
# --------------
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
# print(s.intersection(s1))
#
#         or
#
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
# print(s&s1)
#
# output:
# --------
# set([1, 5])
#
#
#
# difference:
# -----------
#
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
# print(s.difference(s1))
#
#     or
#
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
# print(s-s1)
#
# output:
# -------
# set([2, 'ddd'])
#
#
#
#
# symmetric_difference:
# ---------------------
#
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
# print(s.symmetric_difference(s1))
#
#     or
#
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
# print(s^s1)
#
#
# output:
# -------
# set([0, 2, 3, 4, 12.3, 7, 9, 'ppp', 125, 'ddd'])
#
#
# issubset():
# -----------
#
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125,'ddd',2}
# print(s.issubset(s1))
#
# output:
# --------
# True
#
#
# dictionary:
# -----------
#
# s={'country':'India','State':'Karnataka','city':'Bengaluru'}  #dictionary is unordered, unindexed, key and
# s['State']                                                   #value pairs seperated with : and they are
#                                                               # declared in flower braces ({})
#                                                               ## with keys, we can access values, vice versa is not possible
#
#
# output:
# -------
# 'Karnataka'
#
#
# print only keys from dictionary:
# --------------------------------------
#
# s={'country':'India','State':'Karnataka','city':'Bengaluru'}
# for k in s.keys():
#     print(k)
#
# output:
# -------
#
# country
# State
# city
#
#
#
# print only values from dictionary:
# ----------------------------------
#
# s={'country':'India','State':'Karnataka','city':'Bengaluru'}
# for k in s.values():
#     print(k)
#
#
# output:
# ---------
# India
# Karnataka
# Bengaluru
#
# items:
# ------
# s={'country':'India','State':'Karnataka','city':'Bengaluru'}
# for k in s.items():
#
# output:    #====> in tuple format key and value pairs
# ------
# ('country', 'India')
# ('State', 'Karnataka')
# ('city', 'Bengaluru')
#
#
#
# s={'country':'India','State':'Karnataka','city':'Bengaluru'}
# s['State']=560066        #non-existing key adds a new key value pair in dictionary
# s                       #existing key overrides the actual value in the parent dictionary
#
#
# output:
# -------
# {'State': 560066, 'city': 'Bengaluru', 'country': 'India'}
#
#
# pop() for dictionary:
# ---------------------
# s={'country':'India','State':'Karnataka','city':'Bengaluru'}  #dictionary is mutable
# s.pop('country')    #if pop() is printed, it shows the value that is removed from the list/tuple/set/dictionary
# print(s)
#
# output:
# ------
# {'State': 'Karnataka', 'city': 'Bengaluru'}
#
#
#
#
# s={'country':'India','State':'Karnataka','city':'Bengaluru'}  #dictionary is mutable
# s.popitem()    #if popitem() takes 0 arguements and removes any key: value pair
#
# output:
# -------
# {'State': 'Karnataka', 'city': 'Bengaluru'}
#
#
# del:
# ----
#
# s={'country':'India','State':'Karnataka','city':'Bengaluru'}
# del s['State']
# print(s)
#
# output:
# ------
# {'country': 'India', 'city': 'Bengaluru'}
#
#
# clear():
# -------
#
# s={'country':'India','State':'Karnataka','city':'Bengaluru'}
# s.clear()
# print(s)
#
# output:
# -------
# {}
#
#
#
# thisdict = dict(brand="Ford", model="Mustang", year=1964)
# # note that keywords are not string literals
# # note the use of equals rather than colon for the assignment
# print(thisdict)
#
# output:
# ------
# {'model': 'Mustang', 'brand': 'Ford', 'year': 1964}

# %%
lista=[1,2,3]
lista.del(0)
# Out:
#   File "<ipython-input-5-9ab3fef63c4c>", line 2
#     lista.del(0)
#             ^
# SyntaxError: invalid syntax

# %%
s={1,'ddd',2,5}
s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
print(s.symmetric_difference(s1))
# Out:
# {0, 'ddd', 3, 4, 'ppp', 7, 2, 9, 12.3, 125}

# %% [markdown]
# Intersection:
# --------------
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
# print(s.intersection(s1))
#
#         or
#
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
# print(s&s1)
#
# output:
# --------
# set([1, 5])
#
#
#
# difference:
# -----------
#
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
# print(s.difference(s1))
#
#     or
#
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
# print(s-s1)
#
# output:
# -------
# set([2, 'ddd'])
#
#
#
#
# symmetric_difference:
# ---------------------
#
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
# print(s.symmetric_difference(s1))
#
#     or
#
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
# print(s^s1)

# %%
s1=(1,)
print(type(s1))
# Out:
# <class 'tuple'>

# %% [markdown]
# Union:
# ------
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
# print(s.union(s1))
#
#          or
#
# s={1,'ddd',2,5}
# s1={1,5,5,3,4,7,9,0,'ppp',12.3,125}
# print(s|s1)
#
# output:
# -------
# set([0, 1, 2, 3, 4, 5, 12.3, 7, 9, 'ppp', 125, 'ddd'])
