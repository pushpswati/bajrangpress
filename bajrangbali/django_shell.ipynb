# %% [markdown]
# # Django Env Setup for Notebook

# %%
import os
os.environ["DJANGO_SETTINGS_MODULE"] = "bajrangbali.settings"
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
import django
django.setup()
from bajranapp import models
from bajranapp import serializers
import pprint as pp
import json

# %%
all_data=models.CoronaTracker.objects.all()[:10]

# %%
serializer=serializers.CoronaTrackerSerializers(all_data,many=True)
data=json.loads(json.dumps(serializer.data))

# %%
pp.pprint(data)
# Out:
# [{'FR': 2.9822,
#   'PR': 9.123,
#   'activeCases': 5482,
#   'country': 'India',
#   'countryCode': 'IN',
#   'dailyConfirmed': 321,
#   'dailyDeaths': 8,
#   'id': 1,
#   'lastUpdated': '2020-04-19T10:30:40.598880Z',
#   'lat': 20.593684,
#   'lng': 78.96288,
#   'totalConfirmed': 6237,
#   'totalConfirmedPerMillionPopulation': 5,
#   'totalCritical': 0,
#   'totalDeaths': 186,
#   'totalDeathsPerMillionPopulation': 0,
#   'totalRecovered': 569},
#  {'FR': 2.9822,
#   'PR': 9.123,
#   'activeCases': 5482,
#   'country': 'India',
#   'countryCode': 'IN',
#   'dailyConfirmed': 321,
#   'dailyDeaths': 8,
#   'id': 2,
#   'lastUpdated': '2020-04-19T10:30:40.619933Z',
#   'lat': 20.593684,
#   'lng': 78.96288,
#   'totalConfirmed': 6237,
#   'totalConfirmedPerMillionPopulation': 5,
#   'totalCritical': 0,
#   'totalDeaths': 186,
#   'totalDeathsPerMillionPopulation': 0,
#   'totalRecovered': 569},
#  {'FR': 2.9822,
#   'PR': 9.123,
#   'activeCases': 5482,
#   'country': 'India',
#   'countryCode': 'IN',
#   'dailyConfirmed': 321,
#   'dailyDeaths': 8,
#   'id': 3,
#   'lastUpdated': '2020-04-19T10:30:40.635102Z',
#   'lat': 20.593684,
#   'lng': 78.96288,
#   'totalConfirmed': 6237,
#   'totalConfirmedPerMillionPopulation': 5,
#   'totalCritical': 0,
#   'totalDeaths': 186,
#   'totalDeathsPerMillionPopulation': 0,
#   'totalRecovered': 569},
#  {'FR': 2.9822,
#   'PR': 9.123,
#   'activeCases': 5482,
#   'country': 'India',
#   'countryCode': 'IN',
#   'dailyConfirmed': 321,
#   'dailyDeaths': 8,
#   'id': 4,
#   'lastUpdated': '2020-04-19T10:30:40.650045Z',
#   'lat': 20.593684,
#   'lng': 78.96288,
#   'totalConfirmed': 6237,
#   'totalConfirmedPerMillionPopulation': 5,
#   'totalCritical': 0,
#   'totalDeaths': 186,
#   'totalDeathsPerMillionPopulation': 0,
#   'totalRecovered': 569},
#  {'FR': 2.9822,
#   'PR': 9.123,
#   'activeCases': 5482,
#   'country': 'India',
#   'countryCode': 'IN',
#   'dailyConfirmed': 321,
#   'dailyDeaths': 8,
#   'id': 5,
#   'lastUpdated': '2020-04-19T10:30:40.665779Z',
#   'lat': 20.593684,
#   'lng': 78.96288,
#   'totalConfirmed': 6237,
#   'totalConfirmedPerMillionPopulation': 5,
#   'totalCritical': 0,
#   'totalDeaths': 186,
#   'totalDeathsPerMillionPopulation': 0,
#   'totalRecovered': 569},
#  {'FR': 2.9822,
#   'PR': 9.123,
#   'activeCases': 5482,
#   'country': 'India',
#   'countryCode': 'IN',
#   'dailyConfirmed': 321,
#   'dailyDeaths': 8,
#   'id': 6,
#   'lastUpdated': '2020-04-19T10:30:40.681941Z',
#   'lat': 20.593684,
#   'lng': 78.96288,
#   'totalConfirmed': 6237,
#   'totalConfirmedPerMillionPopulation': 5,
#   'totalCritical': 0,
#   'totalDeaths': 186,
#   'totalDeathsPerMillionPopulation': 0,
#   'totalRecovered': 569},
#  {'FR': 2.9822,
#   'PR': 9.123,
#   'activeCases': 5482,
#   'country': 'India',
#   'countryCode': 'IN',
#   'dailyConfirmed': 321,
#   'dailyDeaths': 8,
#   'id': 7,
#   'lastUpdated': '2020-04-19T10:30:40.705852Z',
#   'lat': 20.593684,
#   'lng': 78.96288,
#   'totalConfirmed': 6237,
#   'totalConfirmedPerMillionPopulation': 5,
#   'totalCritical': 0,
#   'totalDeaths': 186,
#   'totalDeathsPerMillionPopulation': 0,
#   'totalRecovered': 569},
#  {'FR': 2.9822,
#   'PR': 9.123,
#   'activeCases': 5482,
#   'country': 'India',
#   'countryCode': 'IN',
#   'dailyConfirmed': 321,
#   'dailyDeaths': 8,
#   'id': 8,
#   'lastUpdated': '2020-04-19T10:30:40.722018Z',
#   'lat': 20.593684,
#   'lng': 78.96288,
#   'totalConfirmed': 6237,
#   'totalConfirmedPerMillionPopulation': 5,
#   'totalCritical': 0,
#   'totalDeaths': 186,
#   'totalDeathsPerMillionPopulation': 0,
#   'totalRecovered': 569},
#  {'FR': 2.9822,
#   'PR': 9.123,
#   'activeCases': 5482,
#   'country': 'India',
#   'countryCode': 'IN',
#   'dailyConfirmed': 321,
#   'dailyDeaths': 8,
#   'id': 9,
#   'lastUpdated': '2020-04-19T10:30:40.740036Z',
#   'lat': 20.593684,
#   'lng': 78.96288,
#   'totalConfirmed': 6237,
#   'totalConfirmedPerMillionPopulation': 5,
#   'totalCritical': 0,
#   'totalDeaths': 186,
#   'totalDeathsPerMillionPopulation': 0,
#   'totalRecovered': 569},
#  {'FR': 2.9822,
#   'PR': 9.123,
#   'activeCases': 5482,
#   'country': 'India',
#   'countryCode': 'IN',
#   'dailyConfirmed': 321,
#   'dailyDeaths': 8,
#   'id': 10,
#   'lastUpdated': '2020-04-19T10:30:40.756277Z',
#   'lat': 20.593684,
#   'lng': 78.96288,
#   'totalConfirmed': 6237,
#   'totalConfirmedPerMillionPopulation': 5,
#   'totalCritical': 0,
#   'totalDeaths': 186,
#   'totalDeathsPerMillionPopulation': 0,
#   'totalRecovered': 569}]
